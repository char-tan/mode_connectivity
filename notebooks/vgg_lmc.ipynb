# %% [markdown]
# # Setup

# %%
# check GPU
# !nvidia-smi
# Out:
# Wed Dec 28 12:51:34 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# sets .py files to autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# pull repo
# !git clone https://github.com/char-tan/mode_connectivity.git
# Out:
# Cloning into 'mode_connectivity'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 319 (delta 0), reused 1 (delta 0), pack-reused 300
# Receiving objects: 100% (319/319), 6.91 MiB | 5.44 MiB/s, done.
# Resolving deltas: 100% (181/181), done.

# %%
# change working directory
import os
os.chdir('mode_connectivity')

# %%
# checkout branch
# !git checkout wm_other_models
# Out:
# Branch 'wm_other_models' set up to track remote branch 'wm_other_models' from 'origin'.
# Switched to a new branch 'wm_other_models'

# %% [markdown]
# # Train models

# %%
import torch

from training_config import VGG_CIFAR10_DEFAULT
from training import setup_train, train_model

training_config = VGG_CIFAR10_DEFAULT
training_config.epochs = 10
training_config.seed = 7

# train model a
model_a = train_model(*setup_train(training_config), verbose = 1)
torch.save(model_a.state_dict(), 'model_a.pt')

# change seed to get different model
training_config.seed = 42

# train model b
model_b = train_model(*setup_train(training_config), verbose = 1)
torch.save(model_b.state_dict(), 'model_b.pt')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py:204: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Train Epoch: 1, Train Accuracy: (16%)
# Average loss: 2.2080, Accuracy: (23%)
# Train Epoch: 2, Train Accuracy: (23%)
# Average loss: 2.1949, Accuracy: (25%)
# Train Epoch: 3, Train Accuracy: (25%)
# Average loss: 2.1560, Accuracy: (30%)
# Train Epoch: 4, Train Accuracy: (27%)
# Average loss: 2.1525, Accuracy: (30%)
# Train Epoch: 5, Train Accuracy: (29%)
# Average loss: 2.1459, Accuracy: (30%)
# Train Epoch: 6, Train Accuracy: (30%)
# Average loss: 2.1241, Accuracy: (33%)
# Train Epoch: 7, Train Accuracy: (31%)
# Average loss: 2.1432, Accuracy: (31%)
# Train Epoch: 8, Train Accuracy: (31%)
# Average loss: 2.1334, Accuracy: (32%)
# Train Epoch: 9, Train Accuracy: (32%)
# Average loss: 2.1353, Accuracy: (32%)
# Train Epoch: 10, Train Accuracy: (31%)
# Average loss: 2.1162, Accuracy: (34%)
# Train Epoch: 11, Train Accuracy: (33%)
# Average loss: 2.1063, Accuracy: (35%)
# Train Epoch: 12, Train Accuracy: (33%)
# Average loss: 2.1055, Accuracy: (35%)
# Train Epoch: 13, Train Accuracy: (33%)
# Average loss: 2.1177, Accuracy: (34%)
# Train Epoch: 14, Train Accuracy: (34%)
# Average loss: 2.1025, Accuracy: (35%)
# Train Epoch: 15, Train Accuracy: (34%)
# Average loss: 2.0992, Accuracy: (36%)
# Train Epoch: 16, Train Accuracy: (35%)
# Average loss: 2.0952, Accuracy: (36%)
# Train Epoch: 17, Train Accuracy: (34%)
# Average loss: 2.1182, Accuracy: (34%)
# Train Epoch: 18, Train Accuracy: (35%)
# Average loss: 2.0826, Accuracy: (37%)
# Train Epoch: 19, Train Accuracy: (36%)
# Average loss: 2.1050, Accuracy: (35%)
# Train Epoch: 20, Train Accuracy: (36%)
# Average loss: 2.0339, Accuracy: (42%)
# Train Epoch: 35, Train Accuracy: (40%)
# Average loss: 2.0425, Accuracy: (42%)
# Train Epoch: 36, Train Accuracy: (39%)
# Average loss: 2.0631, Accuracy: (40%)
# Train Epoch: 37, Train Accuracy: (40%)
# Average loss: 2.0546, Accuracy: (40%)
# Train Epoch: 38, Train Accuracy: (40%)
# Average loss: 2.0391, Accuracy: (42%)
# Train Epoch: 39, Train Accuracy: (39%)
# Average loss: 2.0374, Accuracy: (42%)
# Train Epoch: 40, Train Accuracy: (40%)
# Average loss: 2.0385, Accuracy: (42%)
# Train Epoch: 41, Train Accuracy: (39%)
# Average loss: 2.0202, Accuracy: (44%)
# Train Epoch: 42, Train Accuracy: (40%)
# Average loss: 2.0615, Accuracy: (40%)
# Train Epoch: 43, Train Accuracy: (41%)
# Average loss: 2.0288, Accuracy: (43%)
# Train Epoch: 44, Train Accuracy: (41%)
# Average loss: 2.0098, Accuracy: (45%)
# Train Epoch: 45, Train Accuracy: (41%)
# Average loss: 2.0504, Accuracy: (41%)
# Train Epoch: 46, Train Accuracy: (41%)
# Average loss: 2.0276, Accuracy: (43%)
# Train Epoch: 47, Train Accuracy: (41%)
# Average loss: 2.0307, Accuracy: (43%)
# Train Epoch: 48, Train Accuracy: (41%)
# Average loss: 2.0359, Accuracy: (42%)
# Train Epoch: 49, Train Accuracy: (41%)
# Average loss: 2.0589, Accuracy: (40%)
# Train Epoch: 50, Train Accuracy: (41%)
# Average loss: 2.0040, Accuracy: (45%)

# %%
from lmc import linear_mode_connect
from models.vgg import VGG

linear_mode_connect(VGG, 'model_a.pt','model_b.pt', "cifar10", n_points = 5, max_iter=10)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# performing naive interpolation
# lam = 0.0, train loss = -0.4259176593017578, test loss = -0.4485730895996094
# lam = 0.25, train loss = -0.34033222610473635, test loss = -0.35654732589721677
# lam = 0.5, train loss = -0.1442849981689453, test loss = -0.14826947021484374
# lam = 0.75, train loss = -0.33283914962768557, test loss = -0.35084851837158204
# lam = 1.0, train loss = -0.4223531854248047, test loss = -0.4497804107666016
#
# permuting model
# iteration 0 P_Conv_3: loss? 4.45733642578125
# iteration 0 P_Conv_20: loss? 1.9513778686523438
# iteration 0 P_Conv_0: loss? 30.018951416015625
# iteration 0 P_Conv_40: loss? 2.982919692993164
# iteration 0 P_Conv_37: loss? 0.7690887451171875
# iteration 0 P_Conv_10: loss? 2.9503021240234375
# iteration 0 P_Conv_27: loss? 1.4945831298828125
# iteration 0 P_Dense_4: loss? 8.43956470489502
# iteration 0 P_Conv_7: loss? 14.240631103515625
# iteration 0 P_Conv_24: loss? 9.693222045898438
# iteration 0 P_Dense_0: loss? 3.1732864379882812
# iteration 0 P_Dense_2: loss? 4.1213154792785645
# iteration 0 P_Conv_34: loss? 1.889174461364746
# iteration 0 P_Conv_30: loss? 4.845245361328125
# iteration 0 P_Conv_14: loss? 6.764137268066406
# iteration 0 P_Conv_17: loss? 11.933418273925781
# iteration 4 P_Conv_40: loss? 0.103973388671875
# iteration 4 P_Conv_10: loss? 0.0
# iteration 4 P_Conv_20: loss? 0.000244140625
# iteration 4 P_Conv_30: loss? 0.0002899169921875
# iteration 4 P_Dense_2: loss? 0.09765481948852539
# iteration 4 P_Conv_7: loss? 0.0
# iteration 5 P_Dense_0: loss? 0.15277767181396484
# iteration 5 P_Conv_34: loss? 0.000247955322265625
# iteration 5 P_Conv_27: loss? 0.0001068115234375
# iteration 5 P_Conv_30: loss? 7.62939453125e-06
# iteration 5 P_Conv_7: loss? 0.0
# iteration 5 P_Conv_37: loss? 0.014293670654296875
# iteration 5 P_Conv_40: loss? 0.001773834228515625
# iteration 5 P_Conv_14: loss? 0.0
# iteration 5 P_Conv_20: loss? 0.0
# iteration 5 P_Conv_3: loss? 0.0
# iteration 5 P_Conv_24: loss? 2.288818359375e-05
# iteration 5 P_Dense_4: loss? 0.0
# iteration 5 P_Conv_0: loss? 0.0
# iteration 5 P_Dense_2: loss? 0.10721206665039062
# iteration 5 P_Conv_10: loss? 0.0
# iteration 5 P_Conv_17: loss? 3.0517578125e-05
# iteration 6 P_Dense_4: loss? 0.0
# iteration 6 P_Conv_34: loss? 0.001338958740234375
# iteration 6 P_Dense_2: loss? 0.0
# iteration 6 P_Conv_10: loss? 0.0
# iteration 6 P_Conv_40: loss? 0.0
# iteration 6 P_Conv_7: loss? 0.0
# iteration 6 P_Conv_37: loss? 6.29425048828125e-05
# iteration 6 P_Conv_0: loss? 0.0
# iteration 6 P_Conv_3: loss? 0.0
# iteration 6 P_Conv_27: loss? 0.0
# iteration 6 P_Conv_20: loss? 0.0
# iteration 6 P_Conv_17: loss? 0.0
# iteration 6 P_Conv_14: loss? 4.57763671875e-05
# iteration 6 P_Conv_30: loss? 4.57763671875e-05
# iteration 6 P_Dense_0: loss? 0.013031959533691406
# iteration 6 P_Conv_24: loss? 0.0
# iteration 7 P_Conv_24: loss? 0.0
# iteration 7 P_Dense_2: loss? 0.027857303619384766
# iteration 7 P_Conv_34: loss? 0.000133514404296875
# iteration 7 P_Conv_30: loss? 0.0001068115234375
# iteration 7 P_Conv_37: loss? 0.0
# iteration 7 P_Conv_17: loss? 1.52587890625e-05
# iteration 7 P_Conv_7: loss? 0.0
# iteration 7 P_Conv_3: loss? 0.0
# iteration 7 P_Dense_0: loss? 0.0018720626831054688
# iteration 7 P_Conv_10: loss? 0.0
# iteration 7 P_Conv_40: loss? 0.00016021728515625
# iteration 7 P_Conv_14: loss? 1.52587890625e-05
# iteration 7 P_Dense_4: loss? 0.0
# iteration 7 P_Conv_27: loss? 0.0
# iteration 7 P_Conv_20: loss? 0.0
# iteration 7 P_Conv_0: loss? 0.0
# iteration 8 P_Conv_27: loss? 0.0
# iteration 8 P_Conv_10: loss? 0.0
# iteration 8 P_Conv_24: loss? 0.0
# iteration 8 P_Conv_3: loss? 0.0
# iteration 8 P_Dense_2: loss? 0.008334159851074219
# iteration 8 P_Conv_37: loss? 0.0
# iteration 8 P_Dense_4: loss? 0.0
# iteration 8 P_Dense_0: loss? 0.0013446807861328125
# iteration 8 P_Conv_7: loss? 0.0
# iteration 8 P_Conv_17: loss? 0.0
# iteration 8 P_Conv_20: loss? 0.0
# iteration 8 P_Conv_0: loss? 0.0
# iteration 8 P_Conv_30: loss? 0.0
# iteration 8 P_Conv_40: loss? 0.0
# iteration 8 P_Conv_34: loss? 5.14984130859375e-05
# iteration 8 P_Conv_14: loss? 0.0
# iteration 9 P_Conv_10: loss? 0.0
# iteration 9 P_Conv_30: loss? 7.62939453125e-06
# iteration 9 P_Conv_17: loss? 0.0
# iteration 9 P_Conv_40: loss? 0.0
# iteration 9 P_Conv_20: loss? 0.0
# iteration 9 P_Conv_34: loss? 3.814697265625e-06
# iteration 9 P_Conv_0: loss? 0.0
# iteration 9 P_Conv_27: loss? 0.0
# iteration 9 P_Conv_24: loss? 0.0
# iteration 9 P_Dense_0: loss? 0.0
# iteration 9 P_Conv_7: loss? 0.0
# iteration 9 P_Dense_4: loss? 0.0
# iteration 9 P_Conv_3: loss? 0.0
# iteration 9 P_Conv_14: loss? 0.0
# iteration 9 P_Conv_37: loss? 0.0
# iteration 9 P_Dense_2: loss? 0.005053520202636719
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-f2485b23f37e> in <module>
#       2 from models.vgg import VGG
#       3
# ----> 4 linear_mode_connect(VGG, 'model_a.pt','model_b.pt', "cifar10", n_points = 5, max_iter=10)
#
# /content/mode_connectivity/lmc.py in linear_mode_connect(model_factory, model_path_a, model_path_b, dataset, batch_size, n_points, max_iter)
#      81
#      82     # perform weight matching and permute model b
# ---> 83     permuted_params = permute_model(model_a.cpu(), model_b.cpu(), max_iter)
#      84
#      85     print('\nperforming permuted interpolation')
#
# /content/mode_connectivity/lmc.py in permute_model(model_a, model_b, max_iter)
#      47
#      48     # applies permutation
# ---> 49     permuted_params = apply_permutation(permutation_spec, permutation, flatten_params(model_b))
#      50
#      51     return permuted_params
#
# /content/mode_connectivity/utils/weight_matching.py in apply_permutation(ps, perm, params)
#     143 def apply_permutation(ps: PermutationSpec, perm, params):
#     144   """Apply a `perm` to `params`."""
# --> 145   return {k: get_permuted_param(ps, perm, k, params) for k in params.keys()}
#     146
#     147 def weight_matching(ps: PermutationSpec, params_a, params_b, max_iter=100, init_perm=None, verbose=2):
#
# /content/mode_connectivity/utils/weight_matching.py in <dictcomp>(.0)
#     143 def apply_permutation(ps: PermutationSpec, perm, params):
#     144   """Apply a `perm` to `params`."""
# --> 145   return {k: get_permuted_param(ps, perm, k, params) for k in params.keys()}
#     146
#     147 def weight_matching(ps: PermutationSpec, params_a, params_b, max_iter=100, init_perm=None, verbose=2):
#
# /content/mode_connectivity/utils/weight_matching.py in get_permuted_param(ps, perm, k, params, except_axis)
#     130   """Get parameter `k` from `params`, with the permutations applied."""
#     131   w = params[k]
# --> 132   for axis, p in enumerate(ps.axes_to_perm[k]):
#     133     # Skip the axis we're trying to permute.
#     134     if axis == except_axis:
#
# KeyError: 'classifier.0.bias'
